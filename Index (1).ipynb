# %% [markdown]
# # Welcome to Jupyter!

# %%
def add(a,b,c):
    return(a+b)/c
a=29
b=3
c=5

d=add(a,b,c)

# %%
d
# Out:
# 6.4

# %%
a,b=6,6
if a>5:
    a+=b

# %%
a,b
# Out:
# (12, 6)

# %%
import numpy as np
a = np.random.randn(100, 100)

# %%
# %timeit np.dot(a, a)
# Out:
# array([[ 0.41870689, -0.73966545, -0.65588522, ..., -0.11334235,
#          1.65343906,  0.87567981],
#        [ 0.2372003 ,  2.16047704,  1.39648118, ...,  0.47407552,
#         -0.77299418, -0.57563891],
#        [-1.29022958, -0.95672647,  0.43142932, ..., -1.68461421,
#          0.71715127, -0.56404684],
#        ...,
#        [-0.68124991, -0.17555108,  0.00316034, ..., -0.13277367,
#          0.24830213,  0.54542419],
#        [-1.25030962, -0.47979265, -1.42047566, ..., -1.62947609,
#          0.41006323, -1.12279822],
#        [ 1.00632347,  0.25169791,  0.76809057, ..., -1.03559533,
#          1.21759931,  0.44035794]])

# %%
# %timeit np.dot(a, a)
# Out:
# 1.31 ms ± 240 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %pwd
# Out:
# '/home/jovyan/binder'

# %%
impo
