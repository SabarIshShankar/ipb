# %%
from google.colab import files
 
 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9b11ff09-74cc-4f3d-9c38-85b1115e59a6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9b11ff09-74cc-4f3d-9c38-85b1115e59a6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving SearchieDailyActives_Mobile_20220608_232600.csv to SearchieDailyActives_Mobile_20220608_232600.csv

# %%
import pandas as pd
import io

df = pd.read_csv(io.BytesIO(uploaded['SearchieDailyActives_Mobile_20220608_232600.csv']))
print(df)
# Out:
#           Date  DailyActiveUsers
# 0   05/09/2022                73
# 1   05/10/2022                75
# 2   05/11/2022                80
# 3   05/12/2022               176
# 4   05/13/2022               131
# 5   05/14/2022                86
# 6   05/15/2022                89
# 7   05/16/2022               101
# 8   05/17/2022                90
# 9   05/18/2022                80
# 10  05/19/2022                94
# 11  05/20/2022                80
# 12  05/21/2022               102
# 13  05/22/2022                80
# 14  05/23/2022                86
# 15  05/24/2022                92
# 16  05/25/2022               169
# 17  05/26/2022                99
# 18  05/27/2022                98
# 19  05/28/2022                84
# 20  05/29/2022                72
# 21  05/30/2022                87
# 22  05/31/2022               110
# 23  06/01/2022                82
# 24  06/02/2022                80
# 25  06/03/2022               111
# 26  06/04/2022               146
# ...

# %%
import seaborn as sns
import matplotlib .pyplot as plt
import numpy as np
from bokeh.plotting import figure, show
from bokeh.models import Legend, LegendItem

# %%
df.describe()
# Out:
#        DailyActiveUsers
# count         30.000000
# mean          96.033333
# std           26.803864
# min           67.000000
# 25%           80.000000
# 50%           86.500000
# 75%          100.500000
# max          176.000000

# %%
plt.plot(df['DailyActiveUsers'])

# %%
plt.plot( df['Date'], df['DailyActiveUsers'], label="DAU")
plt.grid(True)
plt.title('DAU')
plt.ylabel('Users')
plt.xlabel('Date')
# Out:
# Text(0.5, 0, 'Date')

# %%
plt.scatter(df['Date'], df['DailyActiveUsers'], label='DAU')

# %%
plt.hist(df['DailyActiveUsers'], bins=15)
# Out:
# (array([3., 7., 6., 4., 4., 1., 1., 0., 1., 0., 1., 0., 0., 0., 2.]),
#  array([ 67.        ,  74.26666667,  81.53333333,  88.8       ,
#          96.06666667, 103.33333333, 110.6       , 117.86666667,
#         125.13333333, 132.4       , 139.66666667, 146.93333333,
#         154.2       , 161.46666667, 168.73333333, 176.        ]),
#  <a list of 15 Patch objects>)

# %%
sns.pairplot(df)

# %%
sns.set()
sns.scatterplot(df['DailyActiveUsers'], df['Date'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.catplot(y='DailyActiveUsers', kind='violin', data=df )
