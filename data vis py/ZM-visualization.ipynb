# %%
import datetime
# !pip install matplotlib
import matplotlib.pyplot as plot
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/SabarIshShankar/k/main/raw/ZM.csv')
df
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2020-07-20  246.487000  271.350006  245.990005  268.579987  268.579987
# 1    2020-07-21  268.750000  269.750000  258.200012  260.440002  260.440002
# 2    2020-07-22  261.950012  265.399994  255.809998  261.179993  261.179993
# 3    2020-07-23  260.839996  264.899994  249.210007  251.500000  251.500000
# 4    2020-07-24  246.199997  250.210007  237.199997  246.559998  246.559998
# ..          ...         ...         ...         ...         ...         ...
# 246  2021-07-12  385.410004  390.880005  378.269989  379.119995  379.119995
# 247  2021-07-13  379.040009  384.500000  375.410004  378.390015  378.390015
# 248  2021-07-14  380.799988  381.309998  360.450012  360.609985  360.609985
# 249  2021-07-15  363.929993  368.575989  355.350006  356.809998  356.809998
# 250  2021-07-16  359.869995  365.500000  354.339996  361.970001  361.970001
#
#       Volume
# 0    9784900
# 1    4756600
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       251 non-null    object
#  1   Open       251 non-null    float64
#  2   High       251 non-null    float64
#  3   Low        251 non-null    float64
#  4   Close      251 non-null    float64
#  5   Adj Close  251 non-null    float64
#  6   Volume     251 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 13.9+ KB

# %%
df.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  251.000000  251.000000  251.000000  251.000000  251.000000
# mean   372.730917  381.755852  362.982760  372.447988  372.447988
# std     71.571380   73.537651   68.499780   70.475484   70.475484
# min    232.300003  239.399994  230.000000  231.039993  231.039993
# 25%    326.355011  330.664994  317.394989  324.144989  324.144989
# 50%    369.750000  382.500000  360.450012  372.070007  372.070007
# 75%    409.630005  419.899994  400.640000  410.875000  410.875000
# max    572.500000  588.840027  562.549988  568.340027  568.340027
#
#              Volume
# count  2.510000e+02
# mean   6.561046e+06
# std    5.499398e+06
# min    1.437600e+06
# 25%    3.265850e+06
# 50%    4.730000e+06
# 75%    8.282200e+06
# max    5.322620e+07

# %%
df.mean()
# Out:
# C:\Users\OFFICE\AppData\Local\Temp/ipykernel_7244/3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# Open         3.727309e+02
# High         3.817559e+02
# Low          3.629828e+02
# Close        3.724480e+02
# Adj Close    3.724480e+02
# Volume       6.561046e+06
# dtype: float64

# %%
df['Close'].plot(legend=True)
# Out:
# <AxesSubplot:>

# %%
df['Volume'].plot(legend=True)
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns

sns.set_style('whitegrid')

# %%
df['w'] = df['Adj Close'].rolling(window=100, min_periods=0).mean()
print(df.head())
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2020-07-20  246.487000  271.350006  245.990005  268.579987  268.579987
# 1  2020-07-21  268.750000  269.750000  258.200012  260.440002  260.440002
# 2  2020-07-22  261.950012  265.399994  255.809998  261.179993  261.179993
# 3  2020-07-23  260.839996  264.899994  249.210007  251.500000  251.500000
# 4  2020-07-24  246.199997  250.210007  237.199997  246.559998  246.559998
#
#     Volume           w
# 0  9784900  268.579987
# 1  4756600  264.509995
# 2  4581600  263.399994
# 3  4589400  260.424996
# 4  4303200  257.651996

# %%
df['w'].plot()
# Out:
# <AxesSubplot:>

# %%
df['w'] = df['w'].cumsum()
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2020-07-20  246.487000  271.350006  245.990005  268.579987  268.579987
# 1  2020-07-21  268.750000  269.750000  258.200012  260.440002  260.440002
# 2  2020-07-22  261.950012  265.399994  255.809998  261.179993  261.179993
# 3  2020-07-23  260.839996  264.899994  249.210007  251.500000  251.500000
# 4  2020-07-24  246.199997  250.210007  237.199997  246.559998  246.559998
#
#     Volume            w
# 0  9784900   268.579987
# 1  4756600  1070.249956
# 2  4581600  2668.409900
# 3  4589400  5323.484815
# 4  4303200  9293.126697

# %%
df['Open'].plot(figsize=(5,5))
# Out:
# <AxesSubplot:>

# %%
df.plot(figsize=(5,5))
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns

# %%
df.head(23)
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2020-07-20  246.487000  271.350006  245.990005  268.579987  268.579987
# 1   2020-07-21  268.750000  269.750000  258.200012  260.440002  260.440002
# 2   2020-07-22  261.950012  265.399994  255.809998  261.179993  261.179993
# 3   2020-07-23  260.839996  264.899994  249.210007  251.500000  251.500000
# 4   2020-07-24  246.199997  250.210007  237.199997  246.559998  246.559998
# 5   2020-07-27  249.279999  252.970001  246.220001  252.330002  252.330002
# 6   2020-07-28  252.699997  258.910004  251.320007  252.179993  252.179993
# 7   2020-07-29  255.550003  259.929993  251.149994  252.389999  252.389999
# 8   2020-07-30  250.313995  256.325989  239.320007  250.000000  250.000000
# 9   2020-07-31  253.500000  255.199997  248.360001  253.910004  253.910004
# 10  2020-08-03  256.829987  271.100006  256.109985  268.000000  268.000000
# ...

# %%
df['Open'].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['Open'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['Close'].plot.barh()
# Out:
# <AxesSubplot:>

# %%
df['Open'].diff()
# Out:
# 0            NaN
# 1      22.263000
# 2      -6.799988
# 3      -1.110016
# 4     -14.639999
#          ...
# 246     4.390015
# 247    -6.369995
# 248     1.759979
# 249   -16.869995
# 250    -4.059998
# Name: Open, Length: 251, dtype: float64

# %%
df['Close'].diff().plot(kind = 'hist', stacked = True, bins =50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot.scatter(x= 'Volume', y='Close')
# Out:
# <AxesSubplot:xlabel='Volume', ylabel='Close'>

# %%
df.plot.hexbin(x= 'Volume', y='Close',C='Close')
# Out:
# <AxesSubplot:xlabel='Volume', ylabel='Close'>

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df, diagonal='kde')
plot.show()

# %%
scatter_matrix(df, diagonal='kde', figsize=(10,10))
plot.show()
